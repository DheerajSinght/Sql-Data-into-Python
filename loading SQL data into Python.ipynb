# %%
# !pip install mysql-connector-python
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector
import pandas as pd

# %%
ab=mysql.connector.connect(host='localhost',user='root',password='#########',database='data',use_pure=True)

# %%
pd.read_sql_query("select * from course",ab)
# Out:
#    course_id  course_name  course_duration  course_fee
# 0          1      bigdata                6       50000
# 1          2  datascience                6       40000
# 2          3      web dev                3       20000
# 3          4        devop                3       10000

# %%
df=pd.read_sql_query("select * from course",ab)

# %%
df=pd.read_sql_query("select * from students",ab)

# %%
df.head(10)
# Out:
#    student_id student_fname student_lname student_mname  \
# 0           1         sunil         kumar           lal
# 1           2         mohit        sharma        pandit
# 2           3           jai        tanwar       kaushik
# 3           5          raju        tanwar           raj
# 4           6         rahul        pandit         singh
# 5           7      dipendar        tanwar           raj
# 6           8        neeraj        tanwar           raj
#
#                student_email student_phone student_alternate_phone  \
# 0    sunilkumar753@gmail.com    2323232563             89856498989
# 1         mohit753@gmail.com   23256832323              8989896989
# 2          jait753@gmail.com    2323256323              8989898989
# 3    rajusinght753@gmail.com    2359232323              8989895989
# 4   rahulsinght753@gmail.com    9868360361              7878787878
# 5  dineshsinght753@gmail.com    2323232323              8989898989
# ...

# %%
df.shape
# Out:
# (7, 14)

# %%
pd.read_sql_query("select database()",ab)
# Out:
#   database()
# 0       miki

# %%
pd.read_sql_query("desc students",ab)
# Out:
#                       Field         Type Null  Key            Default  \
# 0                student_id          int   NO  PRI               None
# 1             student_fname  varchar(30)   NO                    None
# 2             student_lname  varchar(30)   NO                    None
# 3             student_mname  varchar(30)  YES                    None
# 4             student_email  varchar(30)   NO  UNI               None
# 5             student_phone  varchar(15)   NO                    None
# 6   student_alternate_phone  varchar(15)  YES                    None
# 7          enrollement_date    timestamp   NO       CURRENT_TIMESTAMP
# 8             select_course          int   NO  MUL                  1
# 9               year_of_exp          int   NO                    None
# 10          student_company  varchar(30)  YES                    None
# 11               batch_date  varchar(30)   NO                    None
# ...

# %%
df.to_csv('sql.csv', index=False)
